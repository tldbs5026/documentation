# %% [markdown]
# ## RGB Image Convolution
#
#  - 5x5x3 filter
#  - 32x32x3 image
#  - output : 28x28x1 feature
#
#
# - 32x32x3 image
# - four 5x5x3 filters
# - output : 28x28x4 feature

# %% [markdown]
# ##Stacking of convolution
#
# - input1 : 32x32x4
# - conv1 : (kernel=4, 5x5x3, ReLU)
#
# - input2 : 28x28x4
# - conv2 : (kernel = 10, 5x5x4, ReLU)

# %% [markdown]
# ## 일반적인 CNN
# - Convolution layer, Pooling layer, and FC
#   - Convolution, Pooling : feature extraction
#   - FC : Decision making
#
#
# - FC는 줄어드는 추세

# %% [markdown]
# 학습 시키고자하는 parameter의 수가 늘어날 수록 performance는 감소.
#
# - convolution layer를 증가시키고, parameter를 감소시키는 것이 중요
#   - network의 layer에 따른 parameter수에 대한 이해

# %% [markdown]
# # Stride
#
# - convolution filter의 dense, sparse한 움직임 정의

# %% [markdown]
# # Padding
# - 각 벡터의 끝에 0을 덧댐

# %% [markdown]
# # Convlution Arithmetic
# - padding 1, stride 1, 3x3 kernel
#
# - w:40
# - H:50
# - C:128
#
# result
# - 3x3x128x64 = 73728
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Exercise
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 위의 그래프
# 1. 11x11x3x48 x 2 : 11x11, 3channel, 48 output, 2 model
# 2. 5x5x48x128 x 2 = 307k
# 3. 3x3x128*2 x 192*2
# 4. 3x3x192 x 192x2
# 5. 3x3x192 x 128 * 2
# 6. 13x13x128x2 x 2048 x 2 = 177M
# 7. 2048 x 2 x 2048 x 2 = 16M
# 8. 2048 * 2 x 1000 = 4M

# %% [markdown]
# ##Dense layer의 parameter가 증가하는 이유
#
# - convolution operator가 각각의 kernel이 모든 위치에 동일하게 적용
# - 일종의 shared parameters

# %% [markdown]
# ## 1x1 Convolution
# Dimension reduction
#
# reduce # parameter while increasing the depth
#
#
#
# - input : 256x256x128
# - conv : 1x1x128x32
# - output : 256x256x32
