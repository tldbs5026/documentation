# %% [markdown]
# #Subspace
#
# - 부분공간 : 선형 결합으로 닫힌 공간에 대한 부분 집합
# - subset(부분집합)
# - span과 유사하다고 보면됨

# %% [markdown]
# ## closed
# - 부분집합인 임의의 벡터를 선형결합 했을 때 결과가 이를 만족하는가?
# - 결국 부분공간은 항상 Span_V를 나타냄

# %% [markdown]
# # Basis
#
# - 다음과 같은 조건을 만족할 때 기저라고 한다.
#   1. Fully spans하는 벡터를 갖는 부분공간 H여야 한다.(중복을 허용하지 않음)
#   2. 선형 독립일 경우

# %% [markdown]
# ## 기저벡터
# - unique하지 않음.
# - 기저가 변하면 벡터 값도 바뀜
# - 부분공간 H에 기저는 변하더라도, 그것을 구성하는 vector(차원)은 변하지 않는다.

# %% [markdown]
# Standard Basis
#
# - [1,0,0], [0,1,0], [0,0,1]

# %% [markdown]
# Column space of matrix
#
# - Column으로 이루어진 Span의 집합
# - Span의 부분으로만으로도 정의할 수 있음

# %% [markdown]
# Rank
# - column space의 차원의 개수
# - Rank 가 낮다 == feature의 개수에 비해 얻는 정보가 적다(중복)
