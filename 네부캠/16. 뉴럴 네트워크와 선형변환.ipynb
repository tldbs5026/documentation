# %% [markdown]
# #Fully Connected
#
# 선형변환
#   - 기저의 변화를 주는 것.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Affine Layer
#
# - FC Layer는 대개 bias를 포함함
# - 따라서 선형 layer가 아닌 Affine layer
#
# column combination
# - 입력벡터를 결과차원으로 변환
# - bias 벡터는 상수벡터로 더함
#
# - 키/몸무게/나이 등의 입력벡터와 당뇨/고혈압/폐암 등의 확률 일때,
# - 각 입력벡터의 선형결합으로 결과벡터를 예측할 수 있음.
