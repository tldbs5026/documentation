# %% [markdown]
# # Transformation
#
# - Domain(정의역) : 모든 가능한 x의 value
# - Co-domain(공역) : 모든 가능한 y의 value
# - Image : x가 주어질때 매핑된 output y
# - Range(치역) : x에 의해 매핑된 모든 output value

# %% [markdown]
# # Linear Transformation
#
# - T(cu+dv) = cT(u) + dT(v)
#   - 모든 스칼라 c,d에 대해서 정의역 T를 만족시키는 벡터 u,v
#   - 먼저 선형결합 한 결과가 따로 선형결합 한 결과와 같은 경우

# %% [markdown]
# R2 -> R3의 예시

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 일반적 정의
#
# - Rxn에서 Rxm으로 변환하는 선형 변환인 T가
# - T(X) = Ax for all x < Rxn 일때를 만족해야 한다.
#
# - 여기서, standard matrix인 A는 [T(e1)...T(exn)]
